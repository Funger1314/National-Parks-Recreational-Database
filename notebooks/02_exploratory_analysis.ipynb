# %% [markdown]
# # Recovered Legacy Analysis
#
# This notebook calls the package analysis functions against the recovered dump.

# %%
from pathlib import Path

from national_parks.analysis import (
    advanced_analysis_results,
    load_public_tables,
    original_query_results,
)

dump_path = Path('../database/legacy/NP_Database_postgres_Group1.dump')
tables = load_public_tables(dump_path)
original_results = original_query_results(tables)
advanced_results = advanced_analysis_results(tables)

original_results['q2_visitation_2010_2020']
