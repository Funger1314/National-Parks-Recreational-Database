# %% [markdown]
# # Visitation Data Reconstruction
#
# This notebook demonstrates the package-based visitation workflow instead of duplicating ETL logic inline.

# %%
from pathlib import Path

from national_parks.visitation_cleaning import process_raw_visitation_directory

input_dir = Path('../data/raw/visitation')
output_csv = Path('../data/processed/np_visitation_processed.csv')
quality_csv = Path('../outputs/quality_reports/visitation_quality_report.csv')

process_raw_visitation_directory(
    input_dir=input_dir,
    output_csv=output_csv,
    output_quality_report=quality_csv,
)
